# %% [markdown]
# # Pydantic Basics: Creating and Using Models
# Pydantic models are the foundation of data validation in Python. They use Python type annotations to define the structure and validate data at runtime. Here's a detailed exploration of basic model creation with several examples.

# %%
from pydantic import BaseModel

# %%
from dataclasses import dataclass

@dataclass
class Person():
    name: str
    age: int
    city: str

person = Person(name = "soura", age = 22, city = "kop")

print(person)
# Out:
# Person(name='soura', age=22, city='kop')

# %%
person = Person(name = "soura", age = 22, city = 22)
print(person)
# Out:
# Person(name='soura', age=22, city=22)

# %%
class Person1(BaseModel):
    name: str
    age: int
    city: str

person1 = Person1(name = "soura", age = 22, city = "kop")
print(person1)
# Out:
# name='soura' age=22 city='kop'

# %%
person1 = Person1(name = "soura", age = 22, city = 22)
print(person1)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 person1 = Person1(name = "soura", age = 22, city = 22)
#       2 print(person1)
#
# File c:\Users\soura\OneDrive\Desktop\AgenticAI\.venv\Lib\site-packages\pydantic\main.py:263, in BaseModel.__init__(self, **data)
#     261 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     262 __tracebackhide__ = True
# --> 263 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     264 if self is not validated_self:
#     265     warnings.warn(
#     266         'A custom validator is returning a value other than `self`.\n'
#     267         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
# ...

# %% [markdown]
# # 2. Model with Optional Fields
# Add optional fields using Python's Optional type:

# %%
from typing import Optional

class employee(BaseModel):
    name: str
    age: int
    city: str
    salary: Optional[int] = None
    is_active: Optional[bool] = None

employee1 = employee(name = "soura", age = 22, city = "kop")
print(employee1)
# Out:
# name='soura' age=22 city='kop' salary=None is_active=None

# %%
# Examples with and without optional fields

emp1 = employee(name = "soura", age = 22, city = "kop")
print(emp1)
# Out:
# name='soura' age=22 city='kop' salary=None is_active=None

# %%
emp2 = employee(name = "xyz", age = 30, city = "abc", salary = 50000, is_active = False)
print (emp2)
# Out:
# name='xyz' age=30 city='abc' salary=50000 is_active=False

# %%
emp3 = employee(name = "abc", age = 25, city = "def", salary = "zyz")
print(emp3)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 emp3 = employee(name = "abc", age = 25, city = "def", salary = "zyz")
#       2 print(emp3)
#
# File c:\Users\soura\OneDrive\Desktop\AgenticAI\.venv\Lib\site-packages\pydantic\main.py:263, in BaseModel.__init__(self, **data)
#     261 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     262 __tracebackhide__ = True
# --> 263 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     264 if self is not validated_self:
#     265     warnings.warn(
#     266         'A custom validator is returning a value other than `self`.\n'
#     267         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
# ...

# %% [markdown]
# # Definition:
#
# Optional[type]: Indicates the field can be None
#
# Default value (= None or = True): Makes the field optional
#
# Required fields must still be provided
#
# Pydantic validates types even for optional fields when values are provided

# %%
from typing import Optional
class employee1(BaseModel):
    empid  : int
    name : str
    age : int
    salary : Optional[int] = None
    is_active : Optional[bool] = False

emp = employee1(empid = 1, name = "asd", age = 22, salary = 5000)
print(emp)
emp1 = employee1(empid= 2, name = "aws", age = 30, is_active = True)
print(emp1)
# Out:
# empid=1 name='asd' age=22 salary=5000 is_active=False
# empid=2 name='aws' age=30 salary=None is_active=True
