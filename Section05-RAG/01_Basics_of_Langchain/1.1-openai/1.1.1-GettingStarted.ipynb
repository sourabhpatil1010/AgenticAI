# %% [markdown]
# #### Getting started With Langchain And Open AI
# In this quickstart we'll see how to:
#
# - Get setup with LangChain, LangSmith and LangServe
# - Use the most basic and common components of LangChain: prompt templates, models, and output parsers.
# - Build a simple application with LangChain
# - Trace your application with LangSmith
# - Serve your application with LangServe

# %%
import os
from dotenv import load_dotenv
load_dotenv()

# os.environ['OPENAI_API_KEY']=os.getenv("OPENAI_API_KEY")
## Langsmith Tracking
# os.environ["LANGCHAIN_API_KEY"]=os.getenv("LANGCHAIN_API_KEY")
print("LANGSMITH_TRACING_V21", os.getenv("LANGSMITH_TRACING_V2"))
print("LANGSMITH_TRACING_V22",os.environ["LANGSMITH_TRACING_V2"])
print("LANGSMITH_TRACING_V23",os.environ["LANGSMITH_TRACING_V2"]=="false")
print("LANGSMITH_TRACING_V24",os.environ["LANGCHAIN_TRACING_V2"]=="true")
# os.environ["LANGCHAIN_PROJECT"]=os.getenv("LANGCHAIN_PROJECT")
# Out:
# LANGSMITH_TRACING_V21 None
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 9
#       5 # os.environ['OPENAI_API_KEY']=os.getenv("OPENAI_API_KEY")
#       6 ## Langsmith Tracking
#       7 # os.environ["LANGCHAIN_API_KEY"]=os.getenv("LANGCHAIN_API_KEY")
#       8 print("LANGSMITH_TRACING_V21", os.getenv("LANGSMITH_TRACING_V2"))
# ----> 9 print("LANGSMITH_TRACING_V22",os.environ["LANGSMITH_TRACING_V2"])
#      10 print("LANGSMITH_TRACING_V23",os.environ["LANGSMITH_TRACING_V2"]=="false")
#      11 print("LANGSMITH_TRACING_V24",os.environ["LANGCHAIN_TRACING_V2"]=="true")
#      12 # os.environ["LANGCHAIN_PROJECT"]=os.getenv("LANGCHAIN_PROJECT")
#
# File <frozen os>:717, in _Environ.__getitem__(self, key)
#
# KeyError: 'LANGSMITH_TRACING_V2'

# %%
from langchain_openai import ChatOpenAI
llm=ChatOpenAI(model="gpt-4o")
print(llm)

# %%
from langchain_groq import ChatGroq
llm=ChatGroq(model="openai/gpt-oss-120b")
print(llm)
# Out:
# output_version=None profile={'max_input_tokens': 131072, 'max_output_tokens': 32768, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True} client=<groq.resources.chat.completions.Completions object at 0x00000293340CFCB0> async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x0000029334FD8590> model_name='openai/gpt-oss-120b' model_kwargs={} groq_api_key=SecretStr('**********') groq_api_base=None groq_proxy=None

# %%
## Input and get response form LLM

result=llm.invoke("What is generative AI?")

# %%
print(result.content)
# Out:
# **Generative AI** refers to a class of artificial‑intelligence systems that can **create new content**—such as text, images, audio, video, code, or even 3‑D models—rather than just analyzing or classifying existing data.
#
# ### How It Works
# 1. **Learning Phase (Training)**
#    - The model is fed massive amounts of data (e.g., books, photos, music) and learns statistical patterns, relationships, and structures within that data.
#    - Common architectures:
#      - **Transformer‑based models** (e.g., GPT‑4, BERT, T5) for language.
#      - **Diffusion models** (e.g., Stable Diffusion, DALL‑E 2) and **GANs** (Generative Adversarial Networks) for images and video.
#      - **Variational Autoencoders (VAEs)** and **autoregressive models** for audio, code, etc.
#
# 2. **Generation Phase (Inference)**
#    - Given a prompt, seed, or conditioning signal, the model samples from its learned distribution to produce novel output that resembles the training data but isn’t a direct copy.
# ...

# %%
### Chatprompt template
from langchain_core.prompts import ChatPromptTemplate

prompt=ChatPromptTemplate.from_messages(
    [
        ("system", "Your are an expert AI Engineer. Provide me answer based on the questions"),
        ("user","{input}")
    ]
)
prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Your are an expert AI Engineer. Provide me answer based on the questions'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])

# %%
# Chain
chain = prompt | llm
response = chain.invoke({"input":"can you tell me Landsmith in 20 words"})
print(response.content)
# Out:
# Landsmith is a GIS-based land management platform enabling mapping, analysis, and visualization of spatial data for planning and conservation projects.

# %%
type(response)
# Out:
# langchain_core.messages.ai.AIMessage

# %%
from langchain_core.output_parsers import StrOutputParser
output_parser = StrOutputParser()
chain = prompt | llm | output_parser
response = chain.invoke({"input":"can you tell me Landsmith in 20 words"})
print(response)
# Out:
# Landsmith, a digital platform, streamlines land acquisition, title verification, and documentation, empowering developers, investors, and government agencies efficiently through technology.
