# %% [markdown]
# ### Build a Simple Workflow or Graph Using LangGraph
# #### State
# First, define the State of the graph.
#
# The State schema serves as the input schema for all Nodes and Edges in the graph.
#
# Let's use the TypedDict class from python's typing module as our schema, which provides type hints for the keys.

# %%
from typing_extensions import TypedDict

class State(TypedDict):
    """State of the application."""
    graph_info : str

# %% [markdown]
# ### Nodes
# Nodes are just python functions.
#
# The first positional argument is the state, as defined above.
#
# Because the state is a TypedDict with schema as defined above, each node can access the key, graph_state, with state['graph_state'].
#
# Each node returns a new value of the state key graph_state.
#
# By default, the new value returned by each node will override the prior state value

# %%
import time

def start_play(xyz: State):
    print ("start_paly node has been called")

    return {"graph_info": xyz["graph_info"] + " I am planning to paly"}

def criket(state : State):
    print ("criket node has been called")

    return {"graph_info": state["graph_info"] + " criket"}

def football(state : State):
    print ("football node has been called")

    return {"graph_info": state["graph_info"] + " football"}
def basketball(state : State):
    print("basketball node has been called")
    return {"graph_info": state["graph_info"] + " basketball"}

# %%
import random
random.random()
# Out:
# 0.10327657488497721

# %%
import random
from typing import Literal

def random_play1(state : State) -> Literal["criket", "football", "basketball"]:
     # graph_info=state['graph_info']

     num  = random.random()
     if(num < 0.33):
          return "criket"
     elif num < 0.66:
          return "football"
     else:
          return "basketball"

# %% [markdown]
# ### Graph Construction
# Now, we build the graph from our components defined above.
#
# The StateGraph class is the graph class that we can use.
#
# First, we initialize a StateGraph with the State class we defined above.
#
# Then, we add our nodes and edges.
#
# We use the START Node, a special node that sends user input to the graph, to indicate where to start our graph.
#
# The END Node is a special node that represents a terminal node.
#
# Finally, we compile our graph to perform a few basic checks on the graph structure.
#
# We can visualize the graph as a Mermaid diagram.

# %%
from IPython.display import display, Image
from langgraph.graph import StateGraph, START, END

graph = StateGraph(State)
## Build Graph
graph.add_node("start_play", start_play)
graph.add_node("criket", criket)
graph.add_node("football", football)
graph.add_node("basketball", basketball)

## Schedule the flow of the graph

graph.add_edge(START, "start_play")
graph.add_conditional_edges("start_play",random_play1)
graph.add_edge("criket", END)
graph.add_edge("football", END)
graph.add_edge("basketball", END)

## Compile the graph
graph_builder = graph.compile()

## View
# mermaid = graph_builder.get_graph().draw_mermaid()
# display(Markdown(f"```mermaid\n{mermaid}\n```"))
# display(Image(graph_builder.get_graph().draw_mermaid_png()))
# Show the agent
# from IPython.display import Image, display
# display(Image(graph_builder.get_graph(xray=True).draw_mermaid_png()))

png = graph_builder.get_graph(xray=True).draw_mermaid_png()
display(Image(png))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 2
#       1 from IPython.display import display, Image
# ----> 2 from langgraph.graph import StateGraph, START, END
#       3
#       4 graph = StateGraph(State)
#       5 ## Build Graph
#
# File c:\Users\soura\OneDrive\Desktop\AgenticAI\.venv\Lib\site-packages\langgraph\graph\__init__.py:2
#       1 from langgraph.constants import END, START
# ----> 2 from langgraph.graph.message import MessageGraph, MessagesState, add_messages
#       3 from langgraph.graph.state import StateGraph
#       5 __all__ = (
#       6     "END",
#       7     "START",
#    (...)     11     "MessageGraph",
#      12 )
#
# File c:\Users\soura\OneDrive\Desktop\AgenticAI\.venv\Lib\site-packages\langgraph\graph\message.py:26
#      23 from typing_extensions import TypedDict, deprecated
#      25 from langgraph._internal._constants import CONF, CONFIG_KEY_SEND, NS_SEP
# ---> 26 from langgraph.graph.state import StateGraph
#      27 from langgraph.warnings import LangGraphDeprecatedSinceV10
#      29 __all__ = (
#      30     "add_messages",
#      31     "MessagesState",
#      32     "MessageGraph",
#      33     "REMOVE_ALL_MESSAGES",
#      34 )
#
# File c:\Users\soura\OneDrive\Desktop\AgenticAI\.venv\Lib\site-packages\langgraph\graph\state.py:28
#      14 from types import NoneType as NoneType
#      15 from typing import (
#      16     Any,
#      17     Generic,
#    (...)     25     overload,
#      26 )
# ---> 28 from langchain_core.runnables import Runnable, RunnableConfig
#      29 from langgraph.cache.base import BaseCache
#      30 from langgraph.checkpoint.base import Checkpoint
#
# File c:\Users\soura\OneDrive\Desktop\AgenticAI\.venv\Lib\site-packages\langchain_core\runnables\__init__.py:130, in __getattr__(attr_name)
#     128 def __getattr__(attr_name: str) -> object:
#     129     module_name = _dynamic_imports.get(attr_name)
# --> 130     result = import_attr(attr_name, module_name, __spec__.parent)
#     131     globals()[attr_name] = result
#     132     return result
#
# File c:\Users\soura\OneDrive\Desktop\AgenticAI\.venv\Lib\site-packages\langchain_core\_import_utils.py:39, in import_attr(attr_name, module_name, package)
#      37     except ModuleNotFoundError as err:
#      38         msg = f"module '{package!r}.{module_name!r}' not found ({err})"
# ---> 39         raise ImportError(msg) from None
#      40     result = getattr(module, attr_name)
#      41 return result
#
# ImportError: module ''langchain_core.runnables'.'base'' not found (No module named 'jsonpatch')
